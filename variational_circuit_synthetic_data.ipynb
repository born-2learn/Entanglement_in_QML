# %% [markdown]
# # Effect of Entanglement on Model Training in QML

# %% [markdown]
# ### Importing the required libraries

# %%
from qiskit.ml.datasets import *
from qiskit import QuantumCircuit
from qiskit.aqua.components.optimizers import COBYLA, AQGD, ADAM
from qiskit.circuit.library import ZZFeatureMap, RealAmplitudes
import numpy as np
import matplotlib.pyplot as plt
from qiskit.quantum_info import Statevector, DensityMatrix, entropy
from qiskit import execute
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Loading the Ad Hoc dataset from `qiskit.ml.datasets`

# %%
from sklearn.model_selection import train_test_split

X, y = make_blobs(centers=2, n_features=2)
plt.title("Three blobs...", fontsize='small')
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y,
            s=25, edgecolor='k')

x_train, x_test, y_train, y_test = train_test_split(X, y)
class_labels = ['A', 'B']

# %%
training_input = {'A':[], 'B': []}
for i in range(len(x_train)):
    if y_train[i] == 0:
        training_input['A'].append(x_train[i].tolist())
    else:
        training_input['B'].append(x_train[i].tolist())
training_input['A'] = np.array(training_input['A'])
training_input['B'] = np.array(training_input['B'])

# %%
test_input = {'A':[], 'B': []}
for i in range(len(x_test)):
    if y_test[i] == 0:
        test_input['A'].append(x_test[i].tolist())
    else:
        test_input['B'].append(x_test[i].tolist())
test_input['A'] = np.array(test_input['A'])
test_input['B'] = np.array(test_input['B'])

# %% [markdown]
# ### Preparing the Variational Quantum Classifier Circuit
#
# Use of the `ZZFeatureMap` as the Quantum Feature Map and `Real Amplitudes` as Variational circuit from `qiskit.circuit.library`

# %%
sv = Statevector.from_label('0' * n)
feature_map = ZZFeatureMap(n, reps=1)
var_form = RealAmplitudes(n, reps=1)
circuit = feature_map.combine(var_form)
circuit.draw()
# Out:
#      ┌───┐┌─────────────┐                                          ┌──────────┐»
# q_0: ┤ H ├┤ P(2.0*x[0]) ├──■────────────────────────────────────■──┤ RY(θ[0]) ├»
#      ├───┤├─────────────┤┌─┴─┐┌──────────────────────────────┐┌─┴─┐├──────────┤»
# q_1: ┤ H ├┤ P(2.0*x[1]) ├┤ X ├┤ P(2.0*(π - x[0])*(π - x[1])) ├┤ X ├┤ RY(θ[1]) ├»
#      └───┘└─────────────┘└───┘└──────────────────────────────┘└───┘└──────────┘»
# «          ┌──────────┐
# «q_0: ──■──┤ RY(θ[2]) ├
# «     ┌─┴─┐├──────────┤
# «q_1: ┤ X ├┤ RY(θ[3]) ├
# «     └───┘└──────────┘

# %%
# Preparing the parameter dictionary

def get_data_dict(params, x):
    parameters = {}
    for i, p in enumerate(feature_map.ordered_parameters):
        parameters[p] = x[i]
    for i, p in enumerate(var_form.ordered_parameters):
        parameters[p] = params[i]
    return parameters

# %% [markdown]
# ### Getting a Glimpse of the circuit with initialized parameters

# %%
data = [0.1, 1.2]
params = np.array([0.1, 1.2, 0.02, 0.1])
circ_ = circuit.assign_parameters(get_data_dict(params, data))
circ_.draw(plot_barriers=True)
# Out:
#      ┌───┐┌──────────────────────┐                                 »
# q_0: ┤ H ├┤ P(0.200000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┬┘┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(2.40000000000000) ├─┤ X ├┤ P(11.8110679028453) ├┤ X ├»
#      └───┘└─────────────────────┘ └───┘└─────────────────────┘└───┘»
# «     ┌───────────────────────┐     ┌────────────────────────┐
# «q_0: ┤ RY(0.100000000000000) ├──■──┤ RY(0.0200000000000000) ├
# «     └┬──────────────────────┤┌─┴─┐├───────────────────────┬┘
# «q_1: ─┤ RY(1.20000000000000) ├┤ X ├┤ RY(0.100000000000000) ├─
# «      └──────────────────────┘└───┘└───────────────────────┘

# %% [markdown]
# ### Setting up the environment for Quantum Classification

# %%
def assign_label(bit_string, class_labels):
    hamming_weight = sum([int(k) for k in list(bit_string)])
    is_odd_parity = hamming_weight & 1
    if is_odd_parity:
        return class_labels[1]
    else:
        return class_labels[0]

# %%
def return_probabilities(counts, class_labels):
    shots = sum(counts.values())
    result = {class_labels[0]: 0,
        class_labels[1]: 0}
    for key, item in counts.items():
        label = assign_label(key, class_labels)
        result[label] += counts[key]/shots
    return result

# %%
return_probabilities({'00' : 10, '01': 10, '11': 20}, class_labels)
# Out:
# {'A': 0.75, 'B': 0.25}

# %%
def classify(x_list, params, class_labels):
    qc_list = []
    for x in x_list:
        circ_ = circuit.assign_parameters(get_data_dict(params, x))
        qc = sv.evolve(circ_)
        qc_list += [qc]
    probs = []
    for qc in qc_list:
        counts = qc.to_counts()
        prob = return_probabilities(counts, class_labels)
        probs += [prob]
    return probs

# %%
x = np.asarray([[0.5, 0.9]])
classify(x, params=np.array([0.8, -0.5, 1.5, 0,5]), class_labels=class_labels)
# Out:
# [{'A': 0.9058187060399014, 'B': 0.09418129396009857}]

# %% [markdown]
# ### Defining the Cost function estimate

# %%
def cost_estimate_sigmoid(probs, expected_label): # probability of labels vs actual labels
    p = probs.get(expected_label)
    sig = None
    if np.isclose(p, 0.0):
        sig = 1
    elif np.isclose(p, 1.0):
        sig = 0
    else:
        denominator = np.sqrt(2*p*(1-p))
        x = np.sqrt(200)*(0.5-p)/denominator
        sig = 1/(1+np.exp(-x))
    return sig

# %%
x = np.linspace(0, 1, 20)
y = [cost_estimate_sigmoid({'A': x_, 'B': 1-x_}, 'A') for x_ in x]
plt.plot(x, y)
plt.xlabel('Probability of assigning the correct class')
plt.ylabel('Cost value')
plt.show()

# %% [markdown]
# ### Creating the cost function

# %%
loss_function_values = []
def cost_function(training_input, class_labels, params, shots=100, print_value=False):
    # map training input to list of labels and list of samples
    cost = 0
    training_labels = []
    training_samples = []
    for label, samples in training_input.items():
        for sample in samples:
            training_labels += [label]
            training_samples += [sample]
    # classify all samples
    probs = classify(training_samples, params, class_labels)
    # evaluate costs for all classified samples
    for i, prob in enumerate(probs):
        cost += cost_estimate_sigmoid(prob, training_labels[i])
    cost /= len(training_samples)
    # print resulting objective function
    if print_value:
        loss_function_values.append(cost)
        print('%.4f' % cost)
    # return objective value
    return cost

# %%
cost_function(training_input, class_labels, params)
# Out:
# 0.42270688461279204

# %% [markdown]
# ### Optimizer Setup
#
# We use the ADAM optimizer and save the parameter after every step in a file named `adam_params.csv` by specifying the `snapshot_dir` argument.

# %%
loss_function_values = []
optimizer = ADAM(maxiter=50, snapshot_dir=r'C:\Users\farha\Desktop\Quantum\github-farhan\QOSFProgram')
# define objective function for training
objective_function = lambda params: cost_function(training_input, class_labels, params, print_value=True)
# randomly initialize the parameters
np.random.seed(137)
init_params = 2*np.pi*np.random.rand(n*(1)*2)
# train classifier
# 0.5291
# 0.5291
# 0.5290
# 0.5290
# 0.5290
# 0.5290
# 0.5290
# 0.5289
# 0.5289
# 0.5289
# 0.5289
# 0.5289
# 0.5288
# 0.5288
# 0.5288
# 0.5288
# 0.5288
# 0.5287
# 0.5287
# 0.5287
# 0.5287
# 0.5287
# 0.5286
# 0.5286
# 0.5286
# 0.5286
# 0.5286
# 0.5285
# 0.5285
# 0.5285
# 0.5285
# 0.5285
# 0.5284
# 0.5284
# 0.5284
# 0.5284
# 0.5284
# 0.5283
#
# opt_params: [5.98098437 0.60489986 4.4170257  4.35099431]
# opt_value:  0.5283485470012105

# %% [markdown]
# ## Measuring Entropies as the QML model trains

# %%
vn_entropy = []
epochs = []
epoch_var = 0

import pandas as pd 

# Loading the data from adam_params.csv
df = pd.read_csv(r'C:\Users\farha\Desktop\Quantum\github-farhan\QOSFProgram\adam_params.csv', usecols = ['m'])

arr = df.to_numpy()
param_array = []
for i in arr:
    a_list =i[0].rstrip(']').lstrip('[').split()
    map_object = map(float, a_list)
    list_of_integers = list(map_object)
    param_array.append(list_of_integers)

# %%
print(len(param_array))
print(param_array[0])
# Out:
# 50
# [-0.00138112, -0.00263767, -0.00611378, 0.00321299]

# %% [markdown]
# ### Calculating vonNeumann entropy as the circuit trains
#
# Entropy is measured by calculating the Density Matrix of the state after every iteration and passing it to the `entropy` function from `qiskit.quantum_info` library.

# %%
from qiskit import Aer
vn_entropy = []
epochs = [x for x in range(len(param_array))]
for i in range(len(param_array)):
    x_list = np.asarray([[0.5, 0.9]])
    for x in x_list:
        circ_ = circuit.assign_parameters(get_data_dict(np.array(param_array[i]), x))
        qc = sv.evolve(circ_)
        print(circ_)

    ckt_state = execute(circ_, backend = Aer.get_backend('statevector_simulator'), shots = 500).result().get_statevector()
    D = DensityMatrix(ckt_state)
    vn_entropy_val = entropy(D, base=2)
    vn_entropy.append(vn_entropy_val)
# Out:
# ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0127478700000000) ├──■──┤ RY(-0.0495893600000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0220106300000000) ├┤ X ├─┤ RY(0.0253258900000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0129304700000000) ├──■──┤ RY(-0.0498966500000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0221882200000000) ├┤ X ├─┤ RY(0.0254339700000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0130983700000000) ├──■──┤ RY(-0.0501325800000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0223355100000000) ├┤ X ├─┤ RY(0.0255040400000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0132526900000000) ├──■──┤ RY(-0.0503037300000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0224551800000000) ├┤ X ├─┤ RY(0.0255397900000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0133951400000000) ├──■──┤ RY(-0.0504176900000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0225504600000000) ├┤ X ├─┤ RY(0.0255447600000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0135263400000000) ├──■──┤ RY(-0.0504791700000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0226231100000000) ├┤ X ├─┤ RY(0.0255227000000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0136477400000000) ├──■──┤ RY(-0.0504937600000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0226760600000000) ├┤ X ├─┤ RY(0.0254758700000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0137600100000000) ├──■──┤ RY(-0.0504664800000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0227109400000000) ├┤ X ├─┤ RY(0.0254070800000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0138642700000000) ├──■──┤ RY(-0.0504015100000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0227300200000000) ├┤ X ├─┤ RY(0.0253184100000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0139611000000000) ├──■──┤ RY(-0.0503024100000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0227339700000000) ├┤ X ├─┤ RY(0.0252124100000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0140512500000000) ├──■──┤ RY(-0.0501730300000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0227253200000000) ├┤ X ├─┤ RY(0.0250906900000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0141350400000000) ├──■──┤ RY(-0.0500162800000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0227048700000000) ├┤ X ├─┤ RY(0.0249547200000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0142139000000000) ├──■──┤ RY(-0.0498353500000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0226743700000000) ├┤ X ├─┤ RY(0.0248059300000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0142873100000000) ├──■──┤ RY(-0.0496319900000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0226336000000000) ├┤ X ├─┤ RY(0.0246464800000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0143563800000000) ├──■──┤ RY(-0.0494093300000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0225846900000000) ├┤ X ├─┤ RY(0.0244770000000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0144209900000000) ├──■──┤ RY(-0.0491688600000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0225280100000000) ├┤ X ├─┤ RY(0.0242992600000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0144816900000000) ├──■──┤ RY(-0.0489128000000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0224646800000000) ├┤ X ├─┤ RY(0.0241136500000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0145386500000000) ├──■──┤ RY(-0.0486424900000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0223945900000000) ├┤ X ├─┤ RY(0.0239217300000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0145930200000000) ├──■──┤ RY(-0.0483599100000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0223195100000000) ├┤ X ├─┤ RY(0.0237238000000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0146442900000000) ├──■──┤ RY(-0.0480664000000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0222393900000000) ├┤ X ├─┤ RY(0.0235206900000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0146926500000000) ├──■──┤ RY(-0.0477630500000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0221550700000000) ├┤ X ├─┤ RY(0.0233133500000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0147387300000000) ├──■──┤ RY(-0.0474508400000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0220667500000000) ├┤ X ├─┤ RY(0.0231022100000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0147825300000000) ├──■──┤ RY(-0.0471311000000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0219748300000000) ├┤ X ├─┤ RY(0.0228878600000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0148239500000000) ├──■──┤ RY(-0.0468048200000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0218802200000000) ├┤ X ├─┤ RY(0.0226705300000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0148633400000000) ├──■──┤ RY(-0.0464723000000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0217825300000000) ├┤ X ├─┤ RY(0.0224514000000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0149006800000000) ├──■──┤ RY(-0.0461344000000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0216821700000000) ├┤ X ├─┤ RY(0.0222307500000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0149362800000000) ├──■──┤ RY(-0.0457925400000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0215800800000000) ├┤ X ├─┤ RY(0.0220087400000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0149703200000000) ├──■──┤ RY(-0.0454463500000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0214762000000000) ├┤ X ├─┤ RY(0.0217856200000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0150025000000000) ├──■──┤ RY(-0.0450969100000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0213707300000000) ├┤ X ├─┤ RY(0.0215619400000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘
#      ┌───┐┌─────────────────────┐                                 »
# q_0: ┤ H ├┤ P(1.00000000000000) ├──■───────────────────────────■──»
#      ├───┤├─────────────────────┤┌─┴─┐┌─────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ P(1.80000000000000) ├┤ X ├┤ P(11.8427493721273) ├┤ X ├»
#      └───┘└─────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌─────────────────────────┐     ┌─────────────────────────┐
# «q_0: ┤ RY(-0.0150335900000000) ├──■──┤ RY(-0.0447446700000000) ├
# «     ├─────────────────────────┤┌─┴─┐└┬────────────────────────┤
# «q_1: ┤ RY(-0.0212638100000000) ├┤ X ├─┤ RY(0.0213378600000000) ├
# «     └─────────────────────────┘└───┘ └────────────────────────┘

# %% [markdown]
# ### Calculating Meyer-Wallach entropy as the circuit trains
#
# Meyer Wallach entropy is calculated using the `qutip` library and the implementation is available at `compute_Q_ptrace(ket, N)` function of `meyer_wallach_entanglement.py`.

# %%
from libraries.meyer_wallach_measure import compute_Q_ptrace
mw_entropy = []
epochs = [x for x in range(len(param_array))]
for i in range(len(param_array)):
    x_list = np.asarray([[0.5, 0.9]])
    for x in x_list:
        circ_ = circuit.assign_parameters(get_data_dict(np.array(param_array[i]), x))
        qc = sv.evolve(circ_)
        print(qc)
        k = np.array(list(qc.to_dict().values()))
  
    
    
    mw_val = compute_Q_ptrace(k, 2)
    print(mw_val)
    mw_entropy.append(mw_val)
# Out:
# 20011 +0.09153447j]
#  [-0.0720011 -0.09153447j  0.26448149+0.j        ]]
# 0.9457457595114613
# Statevector([ 0.49052544+0.00435067j, -0.49660245+0.16112346j,
#               0.2464858 +0.44464777j,  0.4600417 +0.12917371j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49052544+0.00435067j]
#  [-0.49660245+0.16112346j]
#  [ 0.2464858 +0.44464777j]
#  [ 0.4600417 +0.12917371j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27677916+0.j         -0.08480285-0.07876718j]
#  [-0.08480285+0.07876718j  0.25036137+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26267129+0.j         -0.07206459+0.09152132j]
#  [-0.07206459-0.09152132j  0.26446924+0.j        ]]
# 0.9457189369789787
# Statevector([ 0.49056217+0.00438143j, -0.49662195+0.16109547j,
#               0.24643462+0.44465869j,  0.4600089 +0.12917001j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49056217+0.00438143j]
#  [-0.49662195+0.16109547j]
#  [ 0.24643462+0.44465869j]
#  [ 0.4600089 +0.12917001j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27683193+0.j         -0.08480207-0.07879899j]
#  [-0.08480207+0.07879899j  0.25032083+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26269819+0.j         -0.07211943+0.09151174j]
#  [-0.07211943-0.09151174j  0.26445457+0.j        ]]
# 0.945694473612583
# Statevector([ 0.49060783+0.00440917j, -0.49662079+0.16107238j,
#               0.24637528+0.44466607j,  0.45999324+0.12917246j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49060783+0.00440917j]
#  [-0.49662079+0.16107238j]
#  [ 0.24637528+0.44466607j]
#  [ 0.45999324+0.12917246j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27687395+0.j         -0.08480184-0.07882841j]
#  [-0.08480184+0.07882841j  0.25028994+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26272612+0.j         -0.07216628+0.09150543j]
#  [-0.07216628-0.09150543j  0.26443778+0.j        ]]
# 0.945672210203194
# Statevector([ 0.49066164+0.00443435j, -0.49660115+0.16105364j,
#               0.24630839+0.44467027j,  0.45999287+0.12918048j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49066164+0.00443435j]
#  [-0.49660115+0.16105364j]
#  [ 0.24630839+0.44467027j]
#  [ 0.45999287+0.12918048j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27690651+0.j         -0.0848021 -0.07885572j]
#  [-0.0848021 +0.07885572j  0.25026755+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26275501+0.j         -0.07220614+0.09150197j]
#  [-0.07220614-0.09150197j  0.26441905+0.j        ]]
# 0.9456518815695927
# Statevector([ 0.49072261+0.00445686j, -0.4965647 +0.16103889j,
#               0.24623511+0.4446716j ,  0.46000641+0.12919354j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49072261+0.00445686j]
#  [-0.4965647 +0.16103889j]
#  [ 0.24623511+0.4446716j ]
#  [ 0.46000641+0.12919354j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27693023+0.j         -0.08480279-0.07888109j]
#  [-0.08480279+0.07888109j  0.25025309+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26278476+0.j         -0.07223937+0.09150126j]
#  [-0.07223937-0.09150126j  0.26439856+0.j        ]]
# 0.945633366316003
# Statevector([ 0.49079004+0.00447725j, -0.49651346+0.16102767j,
#               0.24615585+0.44467035j,  0.46003221+0.1292111j ],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.
0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.2632113 +0.j         -0.072303  +0.09163863j]
#  [-0.072303  -0.09163863j  0.26403977+0.j        ]]
# 0.94549786448313
# Statevector([ 0.4920103 +0.00460753j, -0.49501948+0.16108403j,
#               0.24481593+0.44450887j,  0.46105266+0.12969103j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.4920103 +0.00460753j]
#  [-0.49501948+0.16108403j]
#  [ 0.24481593+0.44450887j]
#  [ 0.46105266+0.12969103j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27671457+0.j         -0.08483885-0.07910714j]
#  [-0.08483885+0.07910714j  0.25053915+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26324519+0.j         -0.07229063+0.09165575j]
#  [-0.07229063-0.09165575j  0.26400852+0.j        ]]
# 0.9454925693710523
# Statevector([ 0.49211781+0.00461054j, -0.49486869+0.1610976j ,
#               0.24470095+0.44448988j,  0.46116081+0.12973912j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49211781+0.00461054j]
#  [-0.49486869+0.1610976j ]
#  [ 0.24470095+0.44448988j]
#  [ 0.46116081+0.12973912j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27667672+0.j         -0.08484235-0.07911746j]
#  [-0.08484235+0.07911746j  0.25057941+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26327907+0.j         -0.07227673+0.09167342j]
#  [-0.07227673-0.09167342j  0.26397705+0.j        ]]
# 0.9454877420113088
# Statevector([ 0.49222602+0.00461273j, -0.49471533+0.16111194j,
#               0.24458551+0.44447037j,  0.4612711 +0.12978808j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49222602+0.00461273j]
#  [-0.49471533+0.16111194j]
#  [ 0.24458551+0.44447037j]
#  [ 0.4612711 +0.12978808j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.2766372 +0.j         -0.0848459 -0.07912724j]
#  [-0.0848459 +0.07912724j  0.25062111+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26331287+0.j         -0.07226141+0.09169158j]
#  [-0.07226141-0.09169158j  0.26394544+0.j        ]]
# 0.9454833744231987
# Statevector([ 0.49233473+0.00461441j, -0.49456003+0.16112689j,
#               0.24446965+0.44445044j,  0.46138302+0.12983769j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49233473+0.00461441j]
#  [-0.49456003+0.16112689j]
#  [ 0.24446965+0.44445044j]
#  [ 0.46138302+0.12983769j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27659644+0.j         -0.08484948-0.07913656j]
#  [-0.08484948+0.07913656j  0.25066387+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26334654+0.j         -0.07224501+0.09171004j]
#  [-0.07224501-0.09171004j  0.26391377+0.j        ]]
# 0.945479381359847
# Statevector([ 0.49244404+0.0046155j , -0.49440278+0.1611424j ,
#               0.24435332+0.4444301j ,  0.46149651+0.12988802j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49244404+0.0046155j ]
#  [-0.49440278+0.1611424j ]
#  [ 0.24435332+0.4444301j ]
#  [ 0.46149651+0.12988802j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27655448+0.j         -0.08485308-0.07914548j]
#  [-0.08485308+0.07914548j  0.25070765+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26338016+0.j         -0.07222759+0.09172884j]
#  [-0.07222759-0.09172884j  0.26388198+0.j        ]]
# 0.9454757297395577
# Statevector([ 0.49255356+0.00461598j, -0.49424397+0.1611585j ,
#               0.24423693+0.44440938j,  0.46161134+0.12993892j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49255356+0.00461598j]
#  [-0.49424397+0.1611585j ]
#  [ 0.24423693+0.44440938j]
#  [ 0.46161134+0.12993892j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27651136+0.j         -0.0848567 -0.07915391j]
#  [-0.0848567 +0.07915391j  0.25075241+0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26341357+0.j         -0.07220911+0.09174791j]
#  [-0.07220911-0.09174791j  0.26385019+0.j        ]]
# 0.9454724707709934
# Statevector([ 0.49266335+0.00461593j, -0.49408387+0.16117498j,
#               0.2441204 +0.44438838j,  0.46172718+0.12999029j],
#             dims=(2, 2))
# KET=   Quantum object: dims = [[2, 2], [1, 1]], shape = (4, 1), type = ket
# Qobj data =
# [[ 0.49266335+0.00461593j]
#  [-0.49408387+0.16117498j]
#  [ 0.2441204 +0.44438838j]
#  [ 0.46172718+0.12999029j]]
# value of n 0 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.27646737+0.j         -0.08486033-0.07916205j]
#  [-0.08486033+0.07916205j  0.2507979 +0.j        ]]
# value of n 1 PTrace:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.26344693+0.j         -0.07218985+0.09176725j]
#  [-0.07218985-0.09176725j  0.26381835+0.j        ]]
# 0.9454694536332415

# %%
# collect coordinates of test data
test_label_0_x = [x[0] for x in test_input[class_labels[0]]]
test_label_0_y = [x[1] for x in test_input[class_labels[0]]]
test_label_1_x = [x[0] for x in test_input[class_labels[1]]]
test_label_1_y = [x[1] for x in test_input[class_labels[1]]]
# initialize lists for misclassified datapoints
test_label_misclassified_x = []
test_label_misclassified_y = []

# evaluate test data
for label, samples in test_input.items():
    # classify samples
    results = classify(samples, opt_params, class_labels)
    # analyze results
    for i, result in enumerate(results):
        # assign label
        assigned_label = class_labels[np.argmax([p for p in result.values()])]
        print('----------------------------------------------------')
        print('Data point: ', samples[i])
        print('Label: ', label)
        print('Assigned: ', assigned_label)
        print('Probabilities: ', result)
        if label != assigned_label:
            print('Classification:', 'INCORRECT')
            test_label_misclassified_x += [samples[i][0]]
            test_label_misclassified_y += [samples[i][1]]
        else:
            print('Classification:', 'CORRECT')
# compute fraction of misclassified samples
total = len(test_label_0_x) + len(test_label_1_x)
num_misclassified = len(test_label_misclassified_x)
print()
print(100*(1-num_misclassified/total), "% of the test data was correctly classified!")
# plot results
plt.figure()
plt.scatter(test_label_0_x, test_label_0_y, c='b', label=class_labels[0], linewidths=5)
plt.scatter(test_label_1_x, test_label_1_y, c='g', label=class_labels[1], linewidths=5)
plt.scatter(test_label_misclassified_x, test_label_misclassified_y, linewidths=20, s=1, facecolors='none',
edgecolors='r')
plt.legend()
plt.show()
# Out:
# ----------------------------------------------------
# Data point:  [-7.46936227 -9.03564571]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.2522543578083472, 'B': 0.7477456421916528}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-7.50627756 -6.67503157]
# Label:  A
# Assigned:  A
# Probabilities:  {'A': 0.5526323645225161, 'B': 0.4473676354774839}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [-6.17450101 -6.50970362]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.19851661806968784, 'B': 0.8014833819303122}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-6.73670747 -6.07489116]
# Label:  A
# Assigned:  A
# Probabilities:  {'A': 0.6586942877464341, 'B': 0.3413057122535659}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [-7.34869338 -7.43627548]
# Label:  A
# Assigned:  A
# Probabilities:  {'A': 0.5950100792118387, 'B': 0.4049899207881613}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [-6.48175501 -6.16098685]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.08940548911996153, 'B': 0.9105945108800384}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-7.73516434 -8.35855813]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.21107053608205684, 'B': 0.7889294639179432}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-7.3553637  -6.74834009]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.3560015816744916, 'B': 0.6439984183255084}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-5.78556158 -7.22059666]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.11503622089276083, 'B': 0.8849637791072391}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-7.83098819 -7.19079287]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.08711759150106942, 'B': 0.9128824084989307}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-6.59505258 -7.16573197]
# Label:  A
# Assigned:  A
# Probabilities:  {'A': 0.9738064815717185, 'B': 0.0261935184282815}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [-5.92960248 -8.53571291]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.4288449074204975, 'B': 0.5711550925795025}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-5.38955212 -7.26186907]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.2683455359615033, 'B': 0.7316544640384968}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-5.0132398  -7.15537694]
# Label:  A
# Assigned:  A
# Probabilities:  {'A': 0.5391201067874364, 'B': 0.4608798932125636}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [-5.95176358 -5.74496577]
# Label:  A
# Assigned:  B
# Probabilities:  {'A': 0.4163872619508908, 'B': 0.5836127380491092}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [-6.27345696 -5.82343893]
# Label:  A
# Assigned:  A
# Probabilities:  {'A': 0.6943177007291347, 'B': 0.3056822992708654}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [5.39132505 8.03888074]
# Label:  B
# Assigned:  A
# Probabilities:  {'A': 0.6187960171110731, 'B': 0.381203982888927}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [5.36347138 8.06940252]
# Label:  B
# Assigned:  A
# Probabilities:  {'A': 0.6402554171303919, 'B': 0.35974458286960814}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [5.2833315 8.282532 ]
# Label:  B
# Assigned:  A
# Probabilities:  {'A': 0.7686729751628059, 'B': 0.2313270248371941}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [6.81090126 6.166554  ]
# Label:  B
# Assigned:  B
# Probabilities:  {'A': 0.2728225777608946, 'B': 0.7271774222391053}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [6.09622991 7.44392284]
# Label:  B
# Assigned:  A
# Probabilities:  {'A': 0.8960724247219733, 'B': 0.10392757527802662}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [5.21070602 6.75410417]
# Label:  B
# Assigned:  A
# Probabilities:  {'A': 0.6228665373705097, 'B': 0.3771334626294902}
# Classification: INCORRECT
# ----------------------------------------------------
# Data point:  [5.43185974 7.31250112]
# Label:  B
# Assigned:  B
# Probabilities:  {'A': 0.3268609723712046, 'B': 0.6731390276287954}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [4.37192642 7.57151861]
# Label:  B
# Assigned:  B
# Probabilities:  {'A': 0.4928494895400002, 'B': 0.5071505104599998}
# Classification: CORRECT
# ----------------------------------------------------
# Data point:  [5.36039975 5.97242972]
# Label:  B
# Assigned:  B
# Probabilities:  {'A': 0.46279778891833523, 'B': 0.5372022110816648}
# Classification: CORRECT
#
# 40.0 % of the test data was correctly classified!

# %% [markdown]
# ## Plotting the results obtained

# %% [markdown]
# ### Number of epochs vs the loss function

# %%
plt.xlabel('Epochs')
plt.ylabel('Loss Function')
plt.title('Cost Function')
plt.plot(epochs, loss_function_values[0:50], color='tab:blue')
plt.show()

# %% [markdown]
# ### Number of epochs vs the von-Neumann entropy measure

# %%
plt.xlabel('Epochs')
plt.ylabel('von Neumann Entropy')
plt.title('S(X)')
plt.plot(epochs, vn_entropy, color='tab:blue')
plt.show()

# %% [markdown]
# ### Number of epochs vs the Meyer Wallach entropy measure

# %%
plt.xlabel('Epochs')
plt.ylabel('Meyer Wallach Entropy')
plt.title('S(X)')
plt.plot(epochs, mw_entropy, color='tab:green')
plt.show()

# %% [markdown]
# ### Loss Function vs the von-Neumann entropy measure

# %%
plt.xlabel('Loss Function')
plt.ylabel('von Neumann Entropy')
plt.title('vN entropy vs loss')
plt.plot( loss_function_values[0:100:2], vn_entropy, color='tab:blue')
plt.show()

# %% [markdown]
# ### Loss function vs the Meyer-Wallach entropy measure

# %%
plt.xlabel('Loss Function')
plt.ylabel('Meyer Wallach Entropy')
plt.title('meyer Wallach vs loss')
plt.plot( loss_function_values[0:50], mw_entropy, color='tab:blue')
plt.show()
